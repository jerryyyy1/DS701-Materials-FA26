# %%
# %pip install -q otter-grader
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initialize Otter
import otter
grader = otter.Notebook()

# %% [markdown]
# # In-Class Exercise 02: Distances, Norms and Similarity
#
# **DS701 — Session 3 (Mon Sep 14, 2026) — Section A1**
#
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tools4ds/DS701-Materials-FA26/blob/main/class_activity_notebooks/02-InClass-Exercise-Distances-A1/02-InClass-Exercise-Distances-A1.ipynb)
#
# **Time: ~60 minutes.** Work in groups of 2–3.
#
# Parts marked **(autograded)** are submitted to Gradescope; open-ended parts are graded
# for participation. You may use AI assistance, but you must be able to explain and
# justify every part of your solution when asked.
#
# **Plan**
#
# | Part | Topic | Grading | Time |
# |---|---|---|---|
# | 1 | Distance functions and a distance matrix, by hand | autograded | ~15 min |
# | 2 | Verify against `scipy` / `sklearn`; check the metric axioms | autograded | ~8 min |
# | 3 | Metric choice and feature scaling change the neighbors | autograded | ~12 min |
# | 4 | **Stretch 1** — the `scikit-learn` `fit` / `transform` pattern | autograded | ~12 min |
# | 5 | **Stretch 2** — dynamic time warping teaser | partly autograded | ~10 min |
# | 6 | Wrap-up: which distance for which data? | participation | ~3 min |
#
# Dependencies: `numpy`, `pandas`, `matplotlib`, `scipy`, `scikit-learn`.

# %% [markdown]
# ## Setup
#
# We use the classic **wine** dataset that ships with `scikit-learn`: 178 wines, 13
# chemical measurements each (alcohol, malic acid, ..., proline), and a label `y` in
# $\{0, 1, 2\}$ giving the grape cultivar. We will **not** use `y` to compute anything —
# distances are unsupervised — but we will peek at it to judge whether a distance is
# putting "similar" wines near each other.
#
# The activity works on a random subset of 60 wines.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
from sklearn.datasets import load_wine
from sklearn.metrics import pairwise
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import Pipeline

# %%
# Lecture section. Only A1 runs this semester; this is kept because the build
# script reads it to name the variant directory the notebook is published in.
SECTION = "A1"
SEED = 701
rng = np.random.default_rng(SEED)

# %%
# Colab: fetch the autograder tests for this activity.
import os, sys, urllib.request

if "google.colab" in sys.modules:
    os.makedirs("tests", exist_ok=True)
    BASE = "https://raw.githubusercontent.com/tools4ds/DS701-Materials-FA26/main/class_activity_notebooks/02-InClass-Exercise-Distances-A1/tests/"
    for _q in ("q1", "q2", "q3", "q4", "q5"):
        urllib.request.urlretrieve(BASE + _q + ".py", "tests/" + _q + ".py")

# %%
wine = load_wine()
feature_names = list(wine.feature_names)

# Each section gets its own 60-wine subset (a seeded permutation of the 178 rows).
subset = rng.permutation(len(wine.data))[:60]
X = wine.data[subset]          # (60, 13) real-valued measurements
y = wine.target[subset]        # cultivar 0/1/2 -- for peeking only
n, d = X.shape

# One wine we will keep asking about: "who are its nearest neighbors?"
QUERY = 0

# A binary version for the set-based distances: 1 if the wine is above the
# subset median on that feature. Row i is then the SET of features on which
# wine i is "high".
B = (X > np.median(X, axis=0)).astype(int)

print(f"section {SECTION}: X is {X.shape}, B is {B.shape}, query wine has cultivar {y[QUERY]}")
pd.DataFrame(X[:5], columns=feature_names).round(2)
# Out:
# section A1: X is (60, 13), B is (60, 13), query wine has cultivar 0
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.20        1.76  2.45               15.2      112.0           3.27
# 1    12.51        1.73  1.98               20.5       85.0           2.20
# 2    14.37        1.95  2.50               16.8      113.0           3.85
# 3    12.21        1.19  1.75               16.8      151.0           1.85
# 4    12.77        2.39  2.28               19.5       86.0           1.39
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.39                  0.34             1.97             6.75  1.05
# 1        1.92                  0.32             1.48             2.94  1.04
# 2        3.49                  0.24             2.18             7.80  0.86
# 3        1.28                  0.14             2.50             2.85  1.28
# 4        0.51                  0.48             0.64             9.90  0.57
#
#    od280/od315_of_diluted_wines  proline
# 0                          2.85   1450.0
# 1                          3.57    672.0
# 2                          3.45   1480.0
# 3                          3.07    718.0
# 4                          1.63    470.0

# %% [markdown]
# Look at the table above before you compute anything: `proline` is in the hundreds,
# `hue` is around 1. Keep that in mind for Part 3.

# %% [markdown]
# ## Part 1 (autograded): distance functions, by hand
#
# Recall the definitions from the lecture. For $\mathbf{u}, \mathbf{v} \in \mathbb{R}^d$:
#
# $$
# \Vert\mathbf{u}-\mathbf{v}\Vert_p = \Big(\sum_i |u_i - v_i|^p\Big)^{1/p},\qquad
# d_{\cos}(\mathbf{u},\mathbf{v}) = 1 - \frac{\mathbf{u}\cdot\mathbf{v}}{\Vert\mathbf{u}\Vert_2\,\Vert\mathbf{v}\Vert_2},\qquad
# d_{J}(a, b) = 1 - \frac{|a \cap b|}{|a \cup b|}
# $$
#
# **Task.** Implement the four functions below with `numpy` only — no `scipy`, no `sklearn`
# in this part. The point is to know exactly what the library does before you call it.
#
# - `lp_distance(u, v, p)` — the Minkowski / $\ell_p$ distance for any `p >= 1`
#   (`p = 1` is Manhattan, `p = 2` is Euclidean). You may treat `p = np.inf` as a bonus.
# - `cosine_distance(u, v)` — $1 - \cos(\mathbf{u}, \mathbf{v})$.
# - `jaccard_distance(a, b)` — for two 0/1 vectors that represent sets: 1 minus
#   intersection-over-union. Convention: two empty sets have distance 0.
# - `distance_matrix(X, dist)` — the $n \times n$ matrix `D[i, j] = dist(X[i], X[j])`
#   for any two-argument distance function `dist`. A double loop is fine here.
#
# Return plain Python `float`s from the first three (wrap with `float(...)`).

# %%
def lp_distance(u, v, p=2):
    """Minkowski distance ||u - v||_p for p >= 1 (p = np.inf gives Chebyshev)."""
    u, v = np.asarray(u, dtype=float), np.asarray(v, dtype=float)
    diff = np.abs(u - v) 
    if p == np.inf: 
        return float(diff.max())
    return float((diff ** p).sum() ** (1.0 / p))


def cosine_distance(u, v):
    """1 - cos(u, v)."""
    u, v = np.asarray(u, dtype=float), np.asarray(v, dtype=float)
    return float(1.0 - (u @ v) / (np.linalg.norm(u) * np.linalg.norm(v)))


def jaccard_distance(a, b):
    """1 - |a & b| / |a | b| for 0/1 vectors a, b (sets). Two empty sets -> 0."""
    a, b = np.asarray(a).astype(bool), np.asarray(b).astype(bool)
    union = np.logical_or(a, b).sum()
    if union == 0:
        return 0.0
    inter = np.logical_and(a, b).sum()
    return float(1.0 - inter / union)


def distance_matrix(X, dist):
    """D[i, j] = dist(X[i], X[j]) for every pair of rows of X."""
    X = np.asarray(X)
    n = X.shape[0]
    D = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            D[i, j] = dist(X[i], X[j])
    return D


# The lecture's warm-up: A = (3, 4), B = (1, 1)
A_pt, B_pt = np.array([3.0, 4.0]), np.array([1.0, 1.0])
print("l1 =", lp_distance(A_pt, B_pt, 1), " l2 =", round(lp_distance(A_pt, B_pt, 2), 4),
      " linf =", lp_distance(A_pt, B_pt, np.inf))
# Out:
# l1 = 5.0  l2 = 3.6056  linf = 3.0

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ## Part 2 (autograded): verify against the libraries, and check the axioms
#
# Now build the four $60 \times 60$ distance matrices for the wine subset and confirm you
# agree with the professionals.
#
# **Task.**
#
# 1. `D_euc`, `D_man`, `D_cos` from **your** `distance_matrix` on `X`, and `D_jac` on the
#    binary matrix `B`.
# 2. The reference versions with `sklearn.metrics.pairwise.euclidean_distances`,
#    `manhattan_distances`, `cosine_distances` (all take a single `X`), and
#    `scipy.spatial.distance.cdist(B, B, 'jaccard')`. Store the **largest absolute
#    difference** between yours and the reference in `err_euc`, `err_man`, `err_cos`,
#    `err_jac` — each should be tiny (`< 1e-8`).
# 3. Write `axiom_report(D)` returning a dict with three booleans —
#    `{'zero_diag': ..., 'symmetric': ..., 'triangle': ...}` — where `triangle` is `True`
#    iff $D_{ij} \le D_{ik} + D_{kj}$ holds for **every** triple $(i, j, k)$ (allow a
#    `1e-9` tolerance). Vectorize it: `D[:, :, None] <= D[:, None, :] + D[None, :, :]`
#    is the whole check in one line.
# 4. Store `axioms_cos = axiom_report(D_cos)`.
#
# Then think: the lecture claims $1 - \cos$ is **not** a metric. Does your `axioms_cos`
# *prove* that, disprove it, or neither? (Discuss in your group; Part 6 asks you to write
# it down.)

# %%
# 1. the four distance matrices, built with MY functions from Part 1
D_euc = distance_matrix(X, lambda u, v: lp_distance(u, v, 2))
D_man = distance_matrix(X, lambda u, v: lp_distance(u, v, 1))
D_cos = distance_matrix(X, cosine_distance)
D_jac = distance_matrix(B, jaccard_distance)

# 2. reference versions from the libraries; store the largest absolute difference
err_euc = float(np.max(np.abs(D_euc - pairwise.euclidean_distances(X))))
err_man = float(np.max(np.abs(D_man - pairwise.manhattan_distances(X))))
err_cos = float(np.max(np.abs(D_cos - pairwise.cosine_distances(X))))
err_jac = float(np.max(np.abs(D_jac - cdist(B, B, 'jaccard'))))

print(f"max |mine - library|: euclid {err_euc:.2e} manhattan {err_man:.2e} cosine {err_cos:.2e} jaccard {err_jac:.2e}")


def axiom_report(D, tol=1e-9):
    """Which metric axioms does the matrix D satisfy?"""
    D = np.asarray(D, dtype=float)
    zero_diag = bool(np.allclose(np.diag(D), 0, atol=tol))
    symmetric = bool(np.allclose(D, D.T, atol=tol))
    triangle = bool(np.all(D[:, :, None] <= D[:, None, :] + D[None, :, :] + tol))
    return {'zero_diag': zero_diag, 'symmetric': symmetric, 'triangle': triangle}


axioms_cos = axiom_report(D_cos)
for name, D in [("euclidean", D_euc), ("manhattan", D_man), ("cosine", D_cos), ("jaccard", D_jac)]:
    print(f"{name:>10}: {axiom_report(D)}")
# Out:
# max |mine - library|: euclid 8.90e-12 manhattan 1.14e-13 cosine 5.55e-16 jaccard 1.11e-16
#  euclidean: {'zero_diag': True, 'symmetric': True, 'triangle': True}
#  manhattan: {'zero_diag': True, 'symmetric': True, 'triangle': True}
#     cosine: {'zero_diag': True, 'symmetric': True, 'triangle': False}
#    jaccard: {'zero_diag': True, 'symmetric': True, 'triangle': True}

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!

# %% [markdown]
# ## Part 3 (autograded): the metric changes the neighbors — and so do the units
#
# A distance matrix is only interesting for what we do with it, and the first thing we
# do is ask **who is near whom**.
#
# **Task 3a — metric choice.** Write `nearest(D, i, k)` returning the indices of the `k`
# nearest neighbors of row `i` according to matrix `D`, closest first, **excluding `i`
# itself**. Then fill the dict `nn_by_metric` with the 5 nearest neighbors of `QUERY`
# under each of `'euclidean'`, `'manhattan'`, `'cosine'`, `'jaccard'` (use your matrices
# from Part 2). Look at how much the four lists agree.
#
# **Task 3b — a fair scoreboard.** One neighbor list is an anecdote. Write
# `loo_1nn_accuracy(D, y)`: for every wine, find its single nearest neighbor (not itself)
# and check whether that neighbor has the same cultivar; return the fraction of wines
# for which it does. This is *leave-one-out 1-nearest-neighbor accuracy* — a number that
# says how well a distance groups "similar" things, using labels only to *score*.
# Store `acc_raw = loo_1nn_accuracy(D_euc, y)`.
#
# **Task 3c — scaling.** Standardize by hand: `X_std = (X - X.mean(axis=0)) / X.std(axis=0)`
# (population std, `ddof=0`). Recompute the Euclidean matrix on `X_std` as `D_euc_std`,
# and store `acc_std = loo_1nn_accuracy(D_euc_std, y)` and
# `nn_std = nearest(D_euc_std, QUERY, 5)`. Finally set `dominant_feature` to the **name**
# of the feature whose variance is the largest share of the total variance in `X`
# (look at `X.var(axis=0)`), and `dominant_share` to that share (a float in $[0,1]$).

# %%
def nearest(D, i, k):
    """Indices of the k nearest rows to row i under D, closest first, excluding i."""
    order = np.argsort(D[i])
    return [int(j) for j in order if j != i][:k]


def loo_1nn_accuracy(D, y):
    """Fraction of rows whose nearest OTHER row (under D) shares its label."""
    y = np.asarray(y)
    hits = [y[nearest(D, i, 1)[0]] == y[i] for i in range(len(y))]
    return float(np.mean(hits))


# 3a
nn_by_metric = {}
for m, D in [('euclidean', D_euc), ('manhattan', D_man), ('cosine', D_cos), ('jaccard', D_jac)]:
    nn_by_metric[m] = nearest(D, QUERY, 5)
for m, idx in nn_by_metric.items():
    print(f"{m:>10}: neighbors {idx} cultivars {y[idx].tolist()} (query is {y[QUERY]})")

# 3b
acc_raw = loo_1nn_accuracy(D_euc, y)

# 3c
X_std = (X - X.mean(axis=0)) / X.std(axis=0)
D_euc_std = distance_matrix(X_std, lambda u, v: lp_distance(u, v, 2))
acc_std = loo_1nn_accuracy(D_euc_std, y)
nn_std = nearest(D_euc_std, QUERY, 5)

var_share = X.var(axis=0) / X.var(axis=0).sum()
dominant_feature = feature_names[int(np.argmax(var_share))]
dominant_share = float(var_share.max())

print(f"\nLOO 1-NN accuracy, Euclidean: raw {acc_raw:.3f} standardized {acc_std:.3f}")
print(f"neighbors of the query, standardized Euclidean: {nn_std} cultivars {y[nn_std].tolist()}")
print(f"{dominant_feature!r} alone carries {100 * dominant_share:.1f}% of the total variance")

# Where does the raw Euclidean distance from the query actually come from?
contrib = ((X - X[QUERY]) ** 2).sum(axis=0)
contrib_s = ((X_std - X_std[QUERY]) ** 2).sum(axis=0)
fig, axes = plt.subplots(1, 2, figsize=(12, 3.8))
axes[0].bar(range(d), contrib / contrib.sum()); axes[0].set_title('share of squared Euclidean distance to the query, RAW')
axes[1].bar(range(d), contrib_s / contrib_s.sum()); axes[1].set_title('same, STANDARDIZED')
for ax in axes:
    ax.set_xticks(range(d)); ax.set_xticklabels(feature_names, rotation=75, fontsize=7); ax.grid(alpha=0.3)
plt.tight_layout(); plt.show()
# Out:
#  euclidean: neighbors [2, 38, 53, 19, 34] cultivars [0, 0, 0, 0, 0] (query is 0)
#  manhattan: neighbors [2, 53, 38, 19, 34] cultivars [0, 0, 0, 0, 0] (query is 0)
#     cosine: neighbors [2, 58, 34, 53, 17] cultivars [0, 0, 0, 0, 0] (query is 0)
#    jaccard: neighbors [54, 17, 20, 58, 16] cultivars [0, 0, 0, 0, 0] (query is 0)
#
# LOO 1-NN accuracy, Euclidean: raw 0.650 standardized 1.000
# neighbors of the query, standardized Euclidean: [54, 34, 2, 58, 53] cultivars [0, 0, 0, 0, 0]
# 'proline' alone carries 99.7% of the total variance

# %% [markdown]
# **Discuss (participation, 2 minutes):** before standardizing, the query's five nearest
# wines under Euclidean and under Manhattan were nearly the same list, and the bar chart on
# the left is one tall bar. Explain both facts with one sentence about `proline`.
#
# Proline is measured in the hundreds while every other feature is orders of magnitude smaller, so proline alone carries ~99.7% of the total variance and single-handedly dominates both the raw Euclidean and Manhattan distances — hence the one tall bar and the nearly identical neighbor lists.

# %%
grader.check("q3")
# Out:
# q3 results: All test cases passed!

# %% [markdown]
# ## Part 4 — Stretch 1 (autograded): the `scikit-learn` `fit` / `transform` pattern
#
# You just standardized by hand. `scikit-learn` does the same thing through an interface
# that *every* object in the library shares — learn it once and you can drive any model:
#
# | kind | learns from data with | then applies with | examples |
# |---|---|---|---|
# | **transformer** | `.fit(X)` | `.transform(X)` (or both at once: `.fit_transform(X)`) | `StandardScaler`, `PCA` |
# | **estimator / model** | `.fit(X, y)` | `.predict(X)` | `KMeans`, `LinearRegression`, `DecisionTreeClassifier` |
#
# Whatever `fit` learns is stored on the object as an attribute ending in an underscore
# (`scaler.mean_`, `scaler.scale_`, `kmeans.cluster_centers_`). A `Pipeline` chains
# transformers and a final estimator into one object with the same `fit` / `predict`
# surface. (Full walkthrough: appendix *A4 Scikit-Learn*.)
#
# **Task.**
#
# 1. `scaler = StandardScaler().fit(X)` — a *fitted* scaler. Check for yourself that
#    `scaler.mean_` equals `X.mean(axis=0)` and `scaler.scale_` equals `X.std(axis=0)`.
# 2. `X_std_sk = scaler.transform(X)`; store `err_scaler = ` the max absolute difference
#    between `X_std_sk` and your hand-made `X_std` from Part 3.
# 3. **The trap.** `x_new` below is a wine the scaler has *not* seen. Produce
#    `x_new_std` by transforming it with the **already-fitted** `scaler` — do **not** call
#    `fit` or `fit_transform` on `x_new`. (Ask yourself what `StandardScaler().fit_transform(x_new)`
#    would return for a single row, and why that would be useless.)
# 4. Build `pipe = Pipeline([('scale', StandardScaler()), ('nn', NearestNeighbors(n_neighbors=6))])`,
#    fit it on `X`, and ask it for the neighbors of the query:
#    `dist_pipe, idx_pipe = pipe.named_steps['nn'].kneighbors(pipe.named_steps['scale'].transform(X[[QUERY]]))`
#    (`n_neighbors=6` because the query itself comes back first). Store
#    `nn_pipe = [int(j) for j in idx_pipe[0] if j != QUERY][:5]` — it should reproduce
#    your `nn_std` from Part 3, proving the pipeline does exactly what you did by hand.

# %%
# 1-2: a fitted transformer stores what it learned as trailing-underscore attributes
scaler = StandardScaler().fit(X)
X_std_sk = scaler.transform(X)
err_scaler = float(np.max(np.abs(X_std_sk - X_std)))
print("scaler.mean_ == X.mean(0):", np.allclose(scaler.mean_, X.mean(axis=0)),
      " scaler.scale_ == X.std(0):", np.allclose(scaler.scale_, X.std(axis=0)),
      f" max |sklearn - by hand| = {err_scaler:.2e}")

# 3: a NEW wine (the mean of the two cultivar-1 wines with the most proline, jittered by section)
_c1 = wine.data[wine.target == 1]
x_new = _c1[np.argsort(_c1[:, -1])[-2:]].mean(axis=0) * (1 + 0.01 * (SEED - 700))
x_new = x_new.reshape(1, -1)
x_new_std = scaler.transform(x_new)  # transform with the ALREADY-FITTED scaler -- never fit on x_new
print("x_new standardized (first 4 features):", np.round(x_new_std[0, :4], 3))

# 4: the same computation as one pipeline object
pipe = Pipeline([('scale', StandardScaler()), ('nn', NearestNeighbors(n_neighbors=6))])
# fit the whole pipeline on X (one call fits the scaler, transforms, then fits the neighbors index):
pipe.fit(X)
dist_pipe, idx_pipe = pipe.named_steps['nn'].kneighbors(pipe.named_steps['scale'].transform(X[[QUERY]]))
nn_pipe = [int(j) for j in idx_pipe[0] if j != QUERY][:5]
print("pipeline neighbors:", nn_pipe, " by hand (Part 3):", nn_std, " agree:", nn_pipe == nn_std)
# Out:
# scaler.mean_ == X.mean(0): True  scaler.scale_ == X.std(0): True  max |sklearn - by hand| = 0.00e+00
# x_new standardized (first 4 features): [-0.041 -0.595  0.253  1.938]
# pipeline neighbors: [54, 34, 2, 58, 53]  by hand (Part 3): [54, 34, 2, 58, 53]  agree: True

# %%
grader.check("q4")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 grader.check("q4")
#
# File d:\Users\DYH\anaconda3\envs\ml_course\Lib\site-packages\otter\check\utils.py:242, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     240 except Exception as e:
#     241     self._log_event(event_type, success=False, error=e)
# --> 242     raise e
#     244 if ret is None:
#     245     ret = LoggedEventReturnValue(None)
#
# File d:\Users\DYH\anaconda3\envs\ml_course\Lib\site-packages\otter\check\utils.py:238, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     233 """
#     234 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     235 of the wrapped function.
#     236 """
#     237 try:
# --> 238     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     240 except Exception as e:
#     241     self._log_event(event_type, success=False, error=e)
#
# File d:\Users\DYH\anaconda3\envs\ml_course\Lib\site-packages\otter\check\notebook.py:256, in Notebook.check(self, question, global_env)
#     243 """
#     244 Runs tests for a specific question against a global environment. If no global environment
#     245 is provided, the test is run against the calling frame's environment.
#    (...)    253     ``otter.test_files.abstract_test.TestFile``: the grade for the question
#     254 """
#     255 self._logger.info(f"Running check for question: {question}")
# --> 256 test_path, test_name = resolve_test_info(
#     257     self._tests_dir,
#     258     self._notebook,
#     259     self._tests_url_prefix,
#     260     question,
#     261 )
#     263 self._logger.debug(f"Resolved test path: {test_path}")
#     264 self._logger.debug(f"Resolved test name: {test_name}")
#
# File d:\Users\DYH\anaconda3\envs\ml_course\Lib\site-packages\otter\check\utils.py:344, in resolve_test_info(tests_dir, nb_path, tests_url_prefix, question)
#     342 elif tests_dir and os.path.isdir(tests_dir):
#     343     if not os.path.isfile(os.path.join(tests_dir, question + ".py")):
# --> 344         raise FileNotFoundError(f"Test {question} does not exist")
#     346     test_path = os.path.join(tests_dir, question + ".py")
#     347     test_name = None
#
# FileNotFoundError: Test q4 does not exist

# %% [markdown]
# ## Part 5 — Stretch 2 (partly autograded): why dynamic time warping exists
#
# Everything so far compared vectors *coordinate by coordinate*: $x_1$ with $y_1$, $x_2$
# with $y_2$. For a **time series** that is a strong assumption — it says the two series
# are perfectly in step. Below, `a` and `b` are the *same* bump, but `b` happens `SHIFT`
# steps later; `c` is a different, flatter shape that happens at the *same* time as `a`.
# Manhattan distance says `c` is closer to `a` than `b` is. Look at the plot and decide
# whether you agree.
#
# **Dynamic time warping** (DTW) fixes this by letting the time axis stretch: it finds the
# cheapest way to *align* the two series, where matching $x_i$ to $y_j$ costs $|x_i - y_j|$
# and the alignment must be monotone and skip nothing. It is a 15-line dynamic program:
#
# ```
# D = (n+1) x (m+1) table of +inf, D[0,0] = 0
# for i in 1..n:
#     for j in 1..m:
#         cost = |x[i-1] - y[j-1]|
#         D[i,j] = cost + min(D[i-1,j], D[i,j-1], D[i-1,j-1])   # insert / delete / match
# return D[n,m]
# ```
#
# **Task.** Implement `dtw_distance(x, y)` exactly as above (return a float), then store
# `man_ab`, `man_ac` (Manhattan, via your `lp_distance` with `p=1`) and `dtw_ab`, `dtw_ac`.
#
# Two facts to check against your numbers: `dtw_distance(x, x) == 0`, and DTW can never
# exceed Manhattan (why? — the diagonal path *is* the coordinate-by-coordinate alignment,
# and DTW takes the minimum over all paths). This is a **teaser**: the full treatment —
# path constraints, backtracking the alignment, edit distance on strings — is the optional
# module *M2 Time Series*.

# %%
# The bump height and the shift for this section.
SHIFT = 3
PEAK = 5
L = 16
bump = np.array([0, 1, 3, PEAK, 3, 1, 0], dtype=float)
a = np.zeros(L); a[2:9] = bump
b = np.zeros(L); b[2 + SHIFT:9 + SHIFT] = bump + np.array([0, 0, 0, 1, 0, 0, 0]) # same bump, later, one unit taller
c = np.zeros(L); c[2:9] = [1, 1, 2, 2, 2, 1, 1] # flat plateau, same time as a

plt.figure(figsize=(9, 3))
plt.plot(a, 'o-', label='a'); plt.plot(b, 's-', label=f'b = a shifted by {SHIFT}'); plt.plot(c, '^-', label='c = plateau')
plt.legend(); plt.grid(alpha=0.3); plt.title('Which is more similar to a: b or c?'); plt.show()


def dtw_distance(x, y):
    """Dynamic time warping distance with |x_i - y_j| step cost (no window)."""
    x, y = np.asarray(x, dtype=float), np.asarray(y, dtype=float)
    n, m = len(x), len(y)
    D = np.full((n + 1, m + 1), np.inf)
    D[0, 0] = 0.0
    for i in range(1, n + 1):
        for j in range(1, m + 1):
            cost = abs(x[i - 1] - y[j - 1])
            D[i, j] = cost + min(D[i - 1, j], D[i, j - 1], D[i - 1, j - 1])  # insert / delete / match
    return float(D[n, m])


man_ab = lp_distance(a, b, 1)
man_ac = lp_distance(a, c, 1)
dtw_ab = dtw_distance(a, b)
dtw_ac = dtw_distance(a, c)
print(f"Manhattan: d(a,b) = {man_ab:.1f} d(a,c) = {man_ac:.1f} -> Manhattan says {'c' if man_ac < man_ab else 'b'} is closer to a")
print(f"DTW: d(a,b) = {dtw_ab:.1f} d(a,c) = {dtw_ac:.1f} -> DTW says {'c' if dtw_ac < dtw_ab else 'b'} is closer to a")

# %% [markdown]
# **Discuss (participation):** DTW gave `d(a, b)` a tiny value even though `b` is shifted.
# Is that always what you want? Name one situation where a time shift *should* count as a
# difference and plain Euclidean/Manhattan is the right call.
#
# No — DTW is only right when the *timing* of the pattern carries no meaning. When timing IS the meaning, a shift should count: e.g., daily traffic or temperature curves, where a rush-hour peak at 8am and the same peak at noon are genuinely different phenomena (likewise a drug reaching peak blood concentration 3 hours late, or a heart-beat response delayed relative to a stimulus). There, plain Euclidean/Manhattan is the right call.

# %%
grader.check("q5")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ## Part 6 (open-ended, participation): which distance for which data?
#
# Staff will circulate and ask your group to explain your reasoning — have your screen and
# your numbers ready. Write brief answers here:
#
# 1. Your `axiom_report(D_cos)` from Part 2 — did it *prove* that $1 - \cos$ is not a
#    metric, disprove it, or neither? What would it take to settle the question?
# 2. Under which distance (Euclidean, Manhattan, cosine, Jaccard, raw or standardized) did
#    the query's neighbors share its cultivar most often, and *why do you think* that one
#    worked best on chemical measurements?
# 3. Give one dataset you know where you would reach for **cosine** first, one for
#    **Jaccard**, and one where a **time shift** should be ignored (DTW) — one phrase each
#    on why.

# %% [markdown]
# 1. It **proved** it — by counterexample. The `triangle` check came back `False`, meaning there is at least one concrete triple of wines with $D_{ij} > D_{ik} + D_{kj}$, and a single counterexample is enough to prove that $1 - \cos$ violates the triangle inequality and is therefore not a metric. (Had the check passed, it would have proved *nothing* — passing on one dataset does not imply the axiom holds for all possible points; that would require a mathematical proof.)
#
# 2. **Standardized Euclidean** worked best: LOO 1-NN accuracy jumped from 0.650 (raw) to 1.000 (standardized). Why: in the raw data, proline's huge scale (~99.7% of total variance) swamps the other 12 measurements, so the distance essentially compares proline alone; standardizing puts all 13 chemical measurements on equal footing, and the cultivars genuinely differ across many of them, so true neighbors share the query's cultivar.
#
# 3. **Cosine first:** text documents as TF-IDF / word-count vectors — only the *mix* of words (direction) matters, not document length (magnitude). **Jaccard:** market-basket or user–item data, e.g., the *set* of products a customer bought — binary presence/absence where shared zeros are meaningless. **DTW (ignore time shift):** speech recognition — the same word spoken faster or slower should be recognized as identical, so the time axis must be allowed to stretch.

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Wrap-up
#
# Before you leave, each group should be able to answer:
#
# 1. State the four metric axioms, and name one "distance" from today that fails one of them.
# 2. Why did standardizing change the neighbors so much on this dataset, and would cosine
#    distance have avoided the problem on its own?
# 3. What does `fit` store on a `StandardScaler`, and why must a new point be `transform`ed
#    with the scaler fitted on the *training* data?
#
# Submit your completed notebook to Gradescope.
